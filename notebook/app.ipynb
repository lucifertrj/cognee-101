# %%
# !uv pip install cognee

# %%
import os
from getpass import getpass

# %%
os.environ['LLM_API_KEY'] = getpass("Enter OpenAI API Key:")

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
import cognee
from cognee.api.v1.visualize.visualize import visualize_graph
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
#
# ...

# %%
MY_PREFERENCE = """
- I like to visit places near the beach where I can find the best spots. 
- I need locations that are rare to find on blogs but are goldmine places for your eyes
- I prefer Vegetarian meals. Use this when I ask for restaurants recommendation
- My hobbies that might also help in planning Itineraries: I love Anime, F1 and Cricket.
"""

# %%
await cognee.prune.prune_data()
await cognee.prune.prune_system(metadata=True)
await cognee.add(MY_PREFERENCE)  
await cognee.cognify()
await visualize_graph("./graph_after_cognify.html")
# await cognee.memify() # to enhance the knowledge graph with memory consolidation for improved connections
# Out:
# 2026-02-13T06:25:58.976060 [info     ] Database deleted successfully. [cognee.shared.logging_utils]
#
# Storage manager absolute path: /usr/local/lib/python3.12/dist-packages/cognee/.cognee_cache
#
# Deleting cache...
#
# ✓ Cache deleted successfully!
#
# NumExpr defaulting to 2 threads.
# User c24c8a3d-0636-4bcf-aa34-eee2c7b3b0cd has registered.
# 2026-02-13T06:26:08.159630 [info     ] Pipeline run started: `1c5bbc8d-3265-55c3-ac3b-72b3b35e5aa9` [run_tasks_with_telemetry()]
#
# 2026-02-13T06:26:08.442309 [info     ] Coroutine task started: `resolve_data_directories` [run_tasks_base]
#
# 2026-02-13T06:26:08.573470 [info     ] Coroutine task started: `ingest_data` [run_tasks_base]
#
# 2026-02-13T06:26:08.754640 [info     ] Registered loader: pypdf_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# 2026-02-13T06:26:08.756085 [info     ] Registered loader: text_loader [cognee.infrastructure.loaders.LoaderEngine]
#
# ...

# %%
prompt = "plan 3 days Itinerary for Hong Kong"
results = await cognee.search(
    query_text = prompt,
    query_type = cognee.SearchType.GRAPH_COMPLETION
)
# Out:
# 2026-02-13T06:45:09.779568 [info     ] Vector collection retrieval completed: Retrieved distances from 6 collections in 29.31s [cognee.shared.logging_utils]
#
# 2026-02-13T06:45:09.780969 [info     ] Retrieving ID-filtered graph from database. [CogneeGraph]
#
# 2026-02-13T06:45:09.789554 [info     ] ID-filtered retrieval: 23 nodes and 38 edges in 0.01s [cognee.shared.logging_utils]
#
# 2026-02-13T06:45:09.792349 [info     ] Graph projection completed: 23 nodes, 38 edges in 0.00s [CogneeGraph]

# %%
from IPython.display import display, Markdown
display(Markdown(results[0]['search_result'][0]))
# Out:
# 3-day Hong Kong itinerary (beach-adjacent, hidden gems, vegetarian-friendly, anime + motorsport/cricket options)
#
# Day 1 — Hong Kong Island: coastal views + anime shopping
# - Morning: Dragon’s Back hike → panoramic viewpoints → descend to Big Wave Bay for a swim and beach photos (great, less-blogged coastal scenery).
# - Lunch: vegetarian-friendly cafe in Shek O / Central (e.g., Grassroots Pantry or a local veg cafe).
# - Afternoon: Stanley Market & Stanley Main Beach (relaxed seaside market vibe). Quick hidden stop: nearby Murray House area and small coastal walk.
# - Evening: Mong Kok anime/manga hunt — Sino Centre / sneaker/manga lanes (Fa Yuen St / Mong Kok streets). Dinner: Pure Veggie House (Kowloon) or veg-friendly noodle/dim-sum spot.
#
# Day 2 — Sai Kung & Geo‑coast hidden gems
# ...
